# %%
# Import dependencies
import pandas as pd
import seaborn as sns

# %%
# Import dataset
nba = pd.read_csv('nba_machine_learning_dataset.csv')

# %%
nba.head()
# Out:
#    Unnamed: 0  active_from  active_to  birth_year  birth_date  Height_in_feet  \
# 0        1454         2015       2018        1995   9/16/1995             6.9
# 1        1670         2016       2018        1994  10/28/1994             6.6
# 2        3994         2014       2014        1993   3/25/1993             6.7
# 3        3159         2015       2018        1991   2/19/1991             6.1
# 4        4378         2016       2018        1993   1/28/1993             6.8
#
#                                              college     height  \
# 0                              University of Arizona   6.9.2020
# 1                             University of Kentucky   6.6.2020
# 2  University of North Carolina, University of Me...   6.7.2020
# 3                          Michigan State University  6.10.2020
# 4            University of California, Santa Barbara   6.8.2020
#
#       player_name position  ...  NCAA_games  NCAA_ppg  Years_played  \
# ...

# %%
# Plot
sns.lmplot(x='Draft_age', y='WinShare/48', data=nba)

# %%
# Plot
sns.lmplot(x='Sprint', y='WinShare/48', data=nba)

# %%
# Plot
sns.lmplot(x='Height_in_feet', y='WinShare/48', data=nba)

# %%
# Plot
sns.lmplot(x='WingSpan', y='WinShare/48', data=nba)

# %%
# Plot
sns.lmplot(x='Standing_vert', y='WinShare/48', data=nba)

# %%
# Plot
sns.lmplot(x='Max_vertical', y='WinShare/48', data=nba)

# %%
# Plot
sns.lmplot(x='Agility', y='WinShare/48', data=nba)

# %%
# Plot
sns.lmplot(x='Sprint', y='WinShare/48', data=nba)

# %%
# Boxplot
sns.boxplot(x='Draft_age', y='WinShare/48', data=nba)

# %%
# Create a visualization
sns.relplot(
    data=nba, x='Draft_age', y='WinShare/48'
)
