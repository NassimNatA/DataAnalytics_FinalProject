# %%
# Import dependencies
import pandas as pd
import seaborn as sns

# %%
# Import dataset
nba = pd.read_csv('output.csv')

# %%
nba.head()
# Out:
#    Unnamed: 0  Position  age  player_height  player_weight  draft_year  \
# 0       10631         2   26         200.66     104.326160        2016
# 1       10632         5   33         190.50      85.275296        2008
# 2       10635         5   25         193.04      95.254320        2014
# 3       10638         4   25         210.82     109.769264        2013
# 4       10640         5   22         200.66      91.625584        2016
#
#    draft_round  draft_number  season  years_played   avg_reb    avg_pts  \
# 0            2            50    2019             3  1.275000   2.925000
# 1            1            26    2019            11  3.125000  11.350000
# 2            1            19    2019             5  2.583333  11.883333
# 3            1            15    2019             6  9.114286  20.500000
# 4            1            26    2019             3  1.766667   5.666667
#
#     avg_ast  last_reb  last_ast  last_pts            player_name   pred_reb  \
# ...

# %%
# Plot
sns.lmplot(x='player_weight', y='pred_reb', data=nba)

# %%
# Plot
sns.lmplot(x='player_height', y='pred_reb', data=nba)

# %%
# Plot
sns.lmplot(x='age', y='pred_reb', data=nba)

# %%
# Plot
sns.lmplot(x='draft_number', y='pred_reb', data=nba)

# %%
# Plot
sns.lmplot(x='years_played', y='pred_reb', data=nba)

# %%
# Plot
sns.lmplot(x='player_weight', y='pred_pts', data=nba)

# %%
# Plot
sns.lmplot(x='player_height', y='pred_pts', data=nba)

# %%
# Plot
sns.lmplot(x='age', y='pred_pts', data=nba)

# %%
# Plot
sns.lmplot(x='draft_number', y='pred_pts', data=nba)

# %%
# Plot
sns.lmplot(x='years_played', y='pred_pts', data=nba)

# %%
# Plot
sns.lmplot(x='player_weight', y='pred_ast', data=nba)

# %%
# Plot
sns.lmplot(x='player_height', y='pred_ast', data=nba)

# %%
# Plot
sns.lmplot(x='draft_number', y='pred_ast', data=nba)

# %%
# Plot
sns.lmplot(x='age', y='pred_ast', data=nba)

# %%
# Plot
sns.lmplot(x='years_played', y='pred_ast', data=nba)
